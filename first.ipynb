# %%
print("你好！这是我的第一个 Jupyter Notebook 代码")
#汁算筒単的数学
result = 5 + 3
print (f"5 + 3 = (result) ")
# Out:
# 你好！这是我的第一个 Jupyter Notebook 代码
# 5 + 3 = (result)

# %%
a = 10
b = 5
sum = a + b
print (f"a+b=(sum)")
# Out:
# a+b=(sum)

# %%
difference = a - b
print(f"a-b = {difference}")
# Out:
# a-b = 5
